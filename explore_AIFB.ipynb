# %% [markdown]
# Simple Dataset Exploration

# %%
import os
import pandas as pd

# Simple relative path for Jupyter
dataset_folder = "AIFB_Dataset"

df = pd.read_csv(os.path.join(dataset_folder, "completeDataset.tsv"), sep='\t')

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (176, 3)
#
# Columns:
# ['id', 'person', 'label_affiliation']
